# %% [markdown]
# <a href="https://colab.research.google.com/github/nipun-taneja/amorphous-yolo/blob/main/notebooks/ResumeFromLastCheckpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ‑run habit is:
#
# Mount Drive → copy project from Drive → work in /content.
#
# Train (new name= for each experiment).
#
# When done → copy /content/amorphous-yolo back to Drive + (optionally) copy that run to checkpoints/.

# %% [markdown]
# # Run Start

# %%
from google.colab import drive
drive.mount('/content/drive')

# Bring repo + data back to /content
# !rm -rf /content/amorphous-yolo
# !cp -r "/content/drive/MyDrive/amorphous-yolo" /content/

# %cd /content/amorphous-yolo

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/checkpoints/amorphous-yolo/baseline_your_dataset/weights/last.pt")
results = model.train(resume=True)

# %% [markdown]
# # Run End: Do this after each experiment

# %%
# !cp -r /content/amorphous-yolo/amorphous-yolo/* "/content/drive/MyDrive/amorphous-yolo"

# %% [markdown]
# change experiment directory below

# %%
# !cp -r /content/amorphous-yolo/amorphous-yolo/runs/detect/experiments/baseline_your_dataset \
      "/content/drive/MyDrive/checkpoints/amorphous-yolo/"
# Out:
# cp: cannot stat '/content/amorphous-yolo/amorphous-yolo/runs/detect/experiments/baseline_your_dataset': No such file or directory
